# %%
import pandas as pd
import pickle
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("employee_attrition.csv")
df.head()
# Out:
#    Age  Gender Department       JobRole  JobLevel  MonthlyIncome  \
# 0   23    Male         IT           SDE         1          25000
# 1   35  Female         HR  HR Executive         3          60000
# 2   29    Male         IT           SDE         2          40000
# 3   45  Female    Finance       Manager         4          80000
# 4   31    Male         IT   QA Engineer         2          45000
#
#    YearsAtCompany OverTime Attrition
# 0               1      Yes       Yes
# 1               5       No        No
# 2               3      Yes       Yes
# 3              10       No        No
# 4               4      Yes       Yes

# %%
X = df.drop("Attrition", axis=1)
y = df["Attrition"]

# %%
num_features = ["Age","MonthlyIncome","YearsAtCompany","JobLevel"]
cat_features = ["Gender","Department","OverTime"]

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), num_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_features)
    ]
)

# %%
pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", LogisticRegression(max_iter=1000))
    ]
)

# %%
pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Age', 'MonthlyIncome',
#                                                    'YearsAtCompany',
#                                                    'JobLevel']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Gender', 'Department',
#                                                    'OverTime'])])),
#                 ('model', LogisticRegression(max_iter=1000))])

# %%
plt.scatter(X["Age"], y)
plt.xlabel("Age")
plt.ylabel("Attrition")
plt.show()

# %%
plt.scatter(X["MonthlyIncome"], y)
plt.xlabel("MonthlyIncome")
plt.ylabel("Attrition")
plt.show()
